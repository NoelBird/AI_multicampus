# %%
import tensorflow as tf
import numpy as np

# %%
sample=" Mulmi team, cheer-up"
#" Mulmi team, cheer-u" -> "Mulmi team, cheer-up"

# %%
idx2char=list(set(sample))
char2idx={c:i for i, c in enumerate(idx2char)}

# %%
dic_size=len(char2idx)
hidden_size=num_classes=dic_size
#dic_size:원핫인코딩크기(rnn input size)
#hidden_size: output size
#num_classes:최종 output size(softmax)
batch_size=1 #데이터 1개 -> 배치 -> 업데이트
sequence_length=len(sample)-1
learning_rate=0.1

# %%
tf.reset_default_graph()
sample_idx=[char2idx[c] for c in sample]
#sample=" Mulmi team, cheer-up"
xdata=[sample_idx[:-1]]
ydata=[sample_idx[1:]]
x=tf.placeholder(tf.int32, [None,sequence_length])
y=tf.placeholder(tf.int32, [None,sequence_length])
x_one_hot=tf.one_hot(x,num_classes)
cell=tf.contrib.rnn.BasicLSTMCell(num_units=hidden_size)
ini_state=cell.zero_state(batch_size, tf.float32)
outputs, _states=tf.nn.dynamic_rnn(cell, x_one_hot, initial_state=ini_state, dtype=tf.float32)

# %%
xfc=tf.reshape(outputs, [-1, hidden_size])
outputs=tf.contrib.layers.fully_connected(xfc, num_classes, activation_fn=None)
outputs=tf.reshape(outputs,[batch_size,sequence_length, num_classes])
weights=tf.ones([batch_size, sequence_length])
sequence_loss=tf.contrib.seq2seq.sequence_loss(logits=outputs, targets=y, weights=weights)
loss=tf.reduce_mean(sequence_loss)
train=tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
prediction=tf.argmax(outputs, axis=2)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(100):
        cv, _=sess.run([loss, train], feed_dict={x:xdata, y:ydata})
        res=sess.run(prediction, feed_dict={x:xdata})
        res_str=[idx2char[c] for c in np.squeeze(res)]
        print(i,"loss:", cv, "prediction:", "".join(res_str))
# Out:
# 0 loss: 2.7076817 prediction: eeu   e  e  uuuuuuuu
# 1 loss: 2.5466664 prediction: eemm         eeeeeee
# 2 loss: 2.3200142 prediction: emmmm meem  eeeeeuuu
# 3 loss: 2.0346828 prediction: emmmmmmmmm    ee   p
# 4 loss: 1.9836344 prediction: eulmm teem  eeeeuuup
# 5 loss: 1.5843931 prediction: eulm  teee, eeeeuupp
# 6 loss: 1.5017675 prediction: eulm  teem  cheer-pp
# 7 loss: 1.2140453 prediction: eulmi teem  cheer-up
# 8 loss: 1.008054 prediction: Mulmi teem, cheer-up
# 9 loss: 0.83967686 prediction: Mulmi teem, cheer-up
# 10 loss: 0.6757988 prediction: Mulmi teem, cheer-up
# 11 loss: 0.526719 prediction: Mulmi teem, cheer-up
# 12 loss: 0.40761495 prediction: Mulmi team, cheer-up
# 13 loss: 0.311414 prediction: Mulmi team, cheer-up
# 14 loss: 0.23282394 prediction: Mulmi team, cheer-up
# 15 loss: 0.17259482 prediction: Mulmi team, cheer-up
# 16 loss: 0.12826566 prediction: Mulmi team, cheer-up
# 17 loss: 0.094826624 prediction: Mulmi team, cheer-up
# 18 loss: 0.0709387 prediction: Mulmi team, cheer-up
# 19 loss: 0.054586977 prediction: Mulmi team, cheer-up
# 20 loss: 0.042246193 prediction: Mulmi team, cheer-up
# 21 loss: 0.03192503 prediction: Mulmi team, cheer-up
# 22 loss: 0.023847759 prediction: Mulmi team, cheer-up
# 23 loss: 0.018222775 prediction: Mulmi team, cheer-up
# 24 loss: 0.014327188 prediction: Mulmi team, cheer-up
# 25 loss: 0.011378927 prediction: Mulmi team, cheer-up
# 26 loss: 0.009141002 prediction: Mulmi team, cheer-up
# 27 loss: 0.007482536 prediction: Mulmi team, cheer-up
# 28 loss: 0.006219848 prediction: Mulmi team, cheer-up
# 29 loss: 0.0052302442 prediction: Mulmi team, cheer-up
# 30 loss: 0.00445006 prediction: Mulmi team, cheer-up
# 31 loss: 0.0038343861 prediction: Mulmi team, cheer-up
# 32 loss: 0.003343042 prediction: Mulmi team, cheer-up
# 33 loss: 0.0029428448 prediction: Mulmi team, cheer-up
# 34 loss: 0.0026095798 prediction: Mulmi team, cheer-up
# 35 loss: 0.0023279241 prediction: Mulmi team, cheer-up
# 36 loss: 0.0020879707 prediction: Mulmi team, cheer-up
# 37 loss: 0.0018829263 prediction: Mulmi team, cheer-up
# 38 loss: 0.0017077501 prediction: Mulmi team, cheer-up
# 39 loss: 0.0015580319 prediction: Mulmi team, cheer-up
# 40 loss: 0.0014299317 prediction: Mulmi team, cheer-up
# 41 loss: 0.0013200768 prediction: Mulmi team, cheer-up
# 42 loss: 0.0012255714 prediction: Mulmi team, cheer-up
# 43 loss: 0.0011439888 prediction: Mulmi team, cheer-up
# 44 loss: 0.0010732267 prediction: Mulmi team, cheer-up
# 45 loss: 0.0010116642 prediction: Mulmi team, cheer-up
# 46 loss: 0.0009578214 prediction: Mulmi team, cheer-up
# 47 loss: 0.0009104983 prediction: Mulmi team, cheer-up
# 48 loss: 0.0008688569 prediction: Mulmi team, cheer-up
# 49 loss: 0.0008319755 prediction: Mulmi team, cheer-up
# 50 loss: 0.00079918234 prediction: Mulmi team, cheer-up
# 51 loss: 0.000769924 prediction: Mulmi team, cheer-up
# 52 loss: 0.00074368936 prediction: Mulmi team, cheer-up
# 53 loss: 0.00072011526 prediction: Mulmi team, cheer-up
# 54 loss: 0.00069876167 prediction: Mulmi team, cheer-up
# 55 loss: 0.00067939615 prediction: Mulmi team, cheer-up
# 56 loss: 0.0006617214 prediction: Mulmi team, cheer-up
# 57 loss: 0.0006454755 prediction: Mulmi team, cheer-up
# 58 loss: 0.000630599 prediction: Mulmi team, cheer-up
# 59 loss: 0.00061678817 prediction: Mulmi team, cheer-up
# 60 loss: 0.0006040134 prediction: Mulmi team, cheer-up
# 61 loss: 0.0005920782 prediction: Mulmi team, cheer-up
# 62 loss: 0.0005809468 prediction: Mulmi team, cheer-up
# 63 loss: 0.0005705478 prediction: Mulmi team, cheer-up
# 64 loss: 0.0005607264 prediction: Mulmi team, cheer-up
# 65 loss: 0.0005514886 prediction: Mulmi team, cheer-up
# 66 loss: 0.00054276286 prediction: Mulmi team, cheer-up
# 67 loss: 0.00053458504 prediction: Mulmi team, cheer-up
# 68 loss: 0.0005267526 prediction: Mulmi team, cheer-up
# 69 loss: 0.00051935477 prediction: Mulmi team, cheer-up
# 70 loss: 0.0005123918 prediction: Mulmi team, cheer-up
# 71 loss: 0.0005057206 prediction: Mulmi team, cheer-up
# 72 loss: 0.0004993948 prediction: Mulmi team, cheer-up
# 73 loss: 0.00049334887 prediction: Mulmi team, cheer-up
# 74 loss: 0.0004875829 prediction: Mulmi team, cheer-up
# 75 loss: 0.00048208487 prediction: Mulmi team, cheer-up
# 76 loss: 0.00047681917 prediction: Mulmi team, cheer-up
# 77 loss: 0.00047180956 prediction: Mulmi team, cheer-up
# 78 loss: 0.00046691898 prediction: Mulmi team, cheer-up
# 79 loss: 0.0004623144 prediction: Mulmi team, cheer-up
# 80 loss: 0.0004578288 prediction: Mulmi team, cheer-up
# 81 loss: 0.000453516 prediction: Mulmi team, cheer-up
# 82 loss: 0.00044938186 prediction: Mulmi team, cheer-up
# 83 loss: 0.00044535496 prediction: Mulmi team, cheer-up
# 84 loss: 0.00044144123 prediction: Mulmi team, cheer-up
# 85 loss: 0.00043765252 prediction: Mulmi team, cheer-up
# 86 loss: 0.00043395913 prediction: Mulmi team, cheer-up
# 87 loss: 0.0004304504 prediction: Mulmi team, cheer-up
# 88 loss: 0.00042695954 prediction: Mulmi team, cheer-up
# 89 loss: 0.00042356394 prediction: Mulmi team, cheer-up
# 90 loss: 0.00042026365 prediction: Mulmi team, cheer-up
# 91 loss: 0.00041705268 prediction: Mulmi team, cheer-up
# 92 loss: 0.00041393106 prediction: Mulmi team, cheer-up
# 93 loss: 0.00041080345 prediction: Mulmi team, cheer-up
# 94 loss: 0.00040776524 prediction: Mulmi team, cheer-up
# 95 loss: 0.00040482232 prediction: Mulmi team, cheer-up
# 96 loss: 0.0004018972 prediction: Mulmi team, cheer-up
# 97 loss: 0.0003990437 prediction: Mulmi team, cheer-up
# 98 loss: 0.00039618407 prediction: Mulmi team, cheer-up
# 99 loss: 0.00039343178 prediction: Mulmi team, cheer-up

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

dataset=[['사과','치즈','생수'],
         ['생수','호두','치즈','고등어'],
         ['수박','사과','생수'],
         ['생수','호두','치즈','옥수수']]

# %%
te=TransactionEncoder()
te_ary=te.fit(dataset).transform(dataset)
te_ary
# Out:
# array([[False,  True,  True, False, False,  True, False],
#        [ True, False,  True, False, False,  True,  True],
#        [False,  True,  True,  True, False, False, False],
#        [False, False,  True, False,  True,  True,  True]])

# %%
df=pd.DataFrame(te_ary, columns=te.columns_)
df
freq_item=apriori(df, min_support=0.5, use_colnames=True)
freq_item
# Out:
#    support      itemsets
# 0     0.50          (사과)
# 1     1.00          (생수)
# 2     0.75          (치즈)
# 3     0.50          (호두)
# 4     0.50      (생수, 사과)
# 5     0.75      (생수, 치즈)
# 6     0.50      (생수, 호두)
# 7     0.50      (치즈, 호두)
# 8     0.50  (생수, 치즈, 호두)

# %%
from mlxtend.frequent_patterns import association_rules
association_rules(freq_item, metric="lift", min_threshold=0.7)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0         (생수)        (사과)                1.00                0.50     0.50
# 1         (사과)        (생수)                0.50                1.00     0.50
# 2         (생수)        (치즈)                1.00                0.75     0.75
# 3         (치즈)        (생수)                0.75                1.00     0.75
# 4         (생수)        (호두)                1.00                0.50     0.50
# 5         (호두)        (생수)                0.50                1.00     0.50
# 6         (치즈)        (호두)                0.75                0.50     0.50
# 7         (호두)        (치즈)                0.50                0.75     0.50
# 8     (생수, 치즈)        (호두)                0.75                0.50     0.50
# 9     (생수, 호두)        (치즈)                0.50                0.75     0.50
# 10    (치즈, 호두)        (생수)                0.50                1.00     0.50
# 11        (생수)    (치즈, 호두)                1.00                0.50     0.50
# 12        (치즈)    (생수, 호두)                0.75                0.50     0.50
# 13        (호두)    (생수, 치즈)                0.50                0.75     0.50
#
#     confidence      lift  leverage  conviction
# 0     0.500000  1.000000     0.000         1.0
# 1     1.000000  1.000000     0.000         inf
# 2     0.750000  1.000000     0.000         1.0
# 3     1.000000  1.000000     0.000         inf
# 4     0.500000  1.000000     0.000         1.0
# 5     1.000000  1.000000     0.000         inf
# 6     0.666667  1.333333     0.125         1.5
# 7     1.000000  1.333333     0.125         inf
# 8     0.666667  1.333333     0.125         1.5
# 9     1.000000  1.333333     0.125         inf
# 10    1.000000  1.000000     0.000         inf
# 11    0.500000  1.000000     0.000         1.0
# 12    0.666667  1.333333     0.125         1.5
# 13    1.000000  1.333333     0.125         inf
